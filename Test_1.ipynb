# %% [markdown]
# ### Test file

# %%
# Addition
print(3 + 5)

# Subtraction
print(10 - 4)

# Multiplication
print(2 * 6)

# Division
print(8 / 2)
# Out:
# 8
# 6
# 12
# 4.0

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a plot
plt.plot(x, y)
plt.title("Simple Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
